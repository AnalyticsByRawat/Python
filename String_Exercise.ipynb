# %% [markdown]
# Q1.
#
# Write a program to input your name and print it.
#
# Q2.
#
# Write a program to print the length of a string.
#
# Q3.
#
# Write a program to print the first and last character of a string.
#
# Q4.
#
# Write a program to count the number of vowels in a string.
#
# Q5.
#
# Write a program to count the number of consonants in a string.
# Given the string:
#
# Q6. text = "Python Programming"
#
# Print:
#
# First character
# Last character
# First 6 characters
# Last 11 characters
# Characters from index 7 to 17
# Every second character
#
# Q7.
#
# Write a program to reverse a string using slicing.
#
# Example
#
# Input: Python
# Output: nohtyP
#
# Q8.
#
# Extract the domain name from an email.
#
# Example
#
# Input: john@gmail.com
# Output: gmail.com
#
# Q9.
#
# Extract the username from an email.
#
# Example
#
# Input: john@gmail.com
# Output: john
#
# Q10.
#
# Write a program to print every alternate character.
#
# Example
#
# Python
# Output: Pto
#
# Q11.
#
# Concatenate first name and last name.
#
# Example
#
# First Name: Rahul
# Last Name: Sharma
#
# Output:
# Rahul Sharma
# Q12.
#
# Join three strings using the + operator.
#
# Q13.
#
# Create the following output using concatenation.
#
# Hello Rahul, Welcome to Python Programming.

# %% [markdown]
# Q14.
#
# Convert a string to uppercase.
#
# Q15.
#
# Convert a string to lowercase.
#
# Q16.
#
# Capitalize the first letter of each word.
#
# Example
#
# python programming language
#
# Output:
# Python Programming Language
# Q17.
#
# Replace "Python" with "Java".
#
# Q18.
#
# Count how many times "Python" appears in a sentence.
#
# Q19.
#
# Check whether a string starts with "https".
#
# Q20.
#
# Check whether a filename ends with ".pdf".
#
# Q21.
#
# Remove leading and trailing spaces.
#
# Q22.
#
# Split the following string.
#
# Apple,Banana,Mango,Grapes
# Q23.
#
# Join a list into a string.
#
# ["Python","Java","C++"]
#
# Output:
#
# Python, Java, C++
# Q24.
#
# Find the position of "Programming" in the string.
#
# Q25.
#
# Check whether "Python" exists in the sentence.

# %% [markdown]
# Q26.
# text = "Python"
#
# print(text[2])
# Q27.
# text = "Programming"
#
# print(text[-4:])
# Q28.
# text = "Python"
#
# print(text[::-1])
# Q29.
# text = "Python"
#
# print(text[::2])
# Q30.
# text = "Hello"
#
# print(text * 3)
# Q31.
# text = "Python"
#
# print(text + " Programming")
# Q32.
# text = "python"
#
# print(text.upper())
# Q33.
# text = "PYTHON"
#
# print(text.lower())
# Q34.
# text = "python programming"
#
# print(text.title())
# Q35.
# text = "Python Programming"
#
# print(text.replace("Python", "Java"))
# Q36.
# text = "Python Python Java Python"
#
# print(text.count("Python"))
# Q37.
# text = "Python"
#
# print(text.startswith("Py"))
# Q38.
# filename = "resume.pdf"
#
# print(filename.endswith(".pdf"))
# Q39.
# text = "   Python   "
#
# print(text.strip())
# Q40.
# text = "Apple,Banana,Mango"
#
# print(text.split(","))
